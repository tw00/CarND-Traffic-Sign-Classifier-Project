# %%
import os
import numpy as np
from scipy import misc

X_test2 = np.empty((0,32,32,3));
directory = 'data-tw';
for filename in os.listdir(directory):
    if filename.endswith(".png"):
        filepath = os.path.join(directory, filename);
        print(filepath);
        img = misc.imread(filepath)
        img = misc.imresize(img,(32,32))   
        img = img[:,:,0:3]
        X_test2 = np.concatenate((X_test2, [img]), axis=0)
        print(img.shape)
        plot_image(img,"");
    else:
        continue
        
X_test2.shape
# Out:
# data-tw/8.png
# (32, 32, 3)
# data-tw/2.png
# (32, 32, 3)
# data-tw/3.png
# (32, 32, 3)
# data-tw/14.png
# (32, 32, 3)
# data-tw/4.png
# (32, 32, 3)
# data-tw/10.png
# (32, 32, 3)
# data-tw/6.png
# (32, 32, 3)
# data-tw/1.png
# (32, 32, 3)
# data-tw/5.png
# (32, 32, 3)
# data-tw/11.png
# (32, 32, 3)
# data-tw/13.png
# (32, 32, 3)
# data-tw/9.png
# (32, 32, 3)
# data-tw/7.png
# (32, 32, 3)
# data-tw/12.png
# (32, 32, 3)
# (14, 32, 32, 3)

# %%
import matplotlib.pyplot as plt
import matplotlib
import scipy.misc
import numpy as np

# %matplotlib inline

def plot_image(image, caption, gray=False):
    # image = X_train[indices[i]].squeeze()
    plt.figure(figsize=(1,1))
    plt.tick_params(axis='x',labelbottom='off')
    plt.tick_params(axis='y',labelleft='off')
    if gray:
        plt.imshow(image, cmap="gray")
    else:
        plt.imshow(image)
    plt.title(caption)
    plt.show()

# %%
import tensorflow as tf
saver = tf.train.Saver()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-1bbae726363e> in <module>()
#       1 import tensorflow as tf
# ----> 2 saver = tf.train.Saver()
#
# /home/carnd/anaconda3/envs/CarND-Traffic-Sign-Classifier-Project/lib/python3.5/site-packages/tensorflow/python/training/saver.py in __init__(self, var_list, reshape, sharded, max_to_keep, keep_checkpoint_every_n_hours, name, restore_sequentially, saver_def, builder, defer_build, allow_empty, write_version, pad_step_number)
#     998     self._pad_step_number = pad_step_number
#     999     if not defer_build:
# -> 1000       self.build()
#    1001     if self.saver_def:
#    1002       self._check_saver_def()
#
# /home/carnd/anaconda3/envs/CarND-Traffic-Sign-Classifier-Project/lib/python3.5/site-packages/tensorflow/python/training/saver.py in build(self)
#    1019           return
#    1020         else:
# -> 1021           raise ValueError("No variables to save")
#    1022       self._is_empty = False
#    1023       self.saver_def = self._builder.build(
#
# ValueError: No variables to save

# %%
with tf.Session() as sess:
    # sess.run(tf.global_variables_initializer())
    
    saver.restore(sess, './lenet_traffic_sign')
    print("Model restored.")    
    
#    pred = predict(X_test2)
    rank = sess.run(tf.nn.top_k(cross_entropy, k=5), feed_dict={x: X_test2, keep_prob: 1. });   
    print(rank)
#    top_k = tf.nn.top_k(cross_entropy, k=5, sorted=True, name=None)
#    rank = sess.run(top_k, feed_dict={x: X_test2, keep_prob: 1.})
#    print(rank)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-9ee6ecf207b1> in <module>()
#       1 import tensorflow as tf
# ----> 2 saver = tf.train.Saver()
#       3
#       4 with tf.Session() as sess:
#       5     # sess.run(tf.global_variables_initializer())
#
# /home/carnd/anaconda3/envs/CarND-Traffic-Sign-Classifier-Project/lib/python3.5/site-packages/tensorflow/python/training/saver.py in __init__(self, var_list, reshape, sharded, max_to_keep, keep_checkpoint_every_n_hours, name, restore_sequentially, saver_def, builder, defer_build, allow_empty, write_version, pad_step_number)
#     998     self._pad_step_number = pad_step_number
#     999     if not defer_build:
# -> 1000       self.build()
#    1001     if self.saver_def:
#    1002       self._check_saver_def()
#
# /home/carnd/anaconda3/envs/CarND-Traffic-Sign-Classifier-Project/lib/python3.5/site-packages/tensorflow/python/training/saver.py in build(self)
#    1019           return
#    1020         else:
# -> 1021           raise ValueError("No variables to save")
#    1022       self._is_empty = False
#    1023       self.saver_def = self._builder.build(
#
# ValueError: No variables to save
